# %% [markdown]
# # Web Scraping - Indeed.com
# General steps for Web Scraping
# 1. Check whether the website allows web scraping
# 2. Obtain the source code (HTML File) by using the website URL
# 3. Download the website content
# 4. Parse the content using keywords tags for elements of interest
# 5. Extract relevant data/features
# 6. Organize raw data in structured format (e.g., CSV)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime
from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ### Path to webdriver (Firefox, Chrome)

# %%
# Ensure that the driver path is correct before running this script.
# Microsoft Windows
driver_path = "/Users/dhairyaparmar/geckodriver"
# Linux
#driver_path = "./drivers/linux/geckodriver"
driver = webdriver.Firefox(executable_path=driver_path)
# Out:
# /var/folders/x_/gv_25j4x4yv_w8_mmgvv_2th0000gn/T/ipykernel_17487/4294398470.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path)

# %% [markdown]
# ### Define position and location

# %%
## Enter a job position
position = "data scientist"
## Enter a location (City, State or Zip or remote)
locations = "remote"

def get_url(position, location):
    url_template = "https://www.indeed.com/jobs?q={}&l={}"
    url = url_template.format(position, location)
    return url

url = get_url(position, locations)
dataframe = pd.DataFrame(columns=["Title", "Company", "Location", "Rating", "Date", "Salary", "Description", "Links"])

# %% [markdown]
# ### Scrape job postings

# %%
## Number of postings to scrape
postings = 100

jn=0
for i in range(0, postings, 10):
    driver.get(url + "&start=" + str(i))
    driver.implicitly_wait(3)

    jobs = driver.find_elements(By.CLASS_NAME, 'job_seen_beacon')

    for job in jobs:
        result_html = job.get_attribute('innerHTML')
        soup = BeautifulSoup(result_html, 'html.parser')
        
        jn += 1
        
        liens = job.find_elements(By.TAG_NAME, "a")
        links = liens[0].get_attribute("href")
        
        title = soup.select('.jobTitle')[0].get_text().strip()
        company = soup.select('.companyName')[0].get_text().strip()
        location = soup.select('.companyLocation')[0].get_text().strip()
        try:
            salary = soup.select('.salary-snippet-container')[0].get_text().strip()
        except:
            salary = 'NaN'
        try:
            rating = soup.select('.ratingNumber')[0].get_text().strip()
        except:
            rating = 'NaN'
        try:
            date = soup.select('.date')[0].get_text().strip()
        except:
            date = 'NaN'
        try:
            description = soup.select('.job-snippet')[0].get_text().strip()
        except:
            description = ''
       
        dataframe = pd.concat([dataframe, pd.DataFrame([{'Title': title,
                                          "Company": company,
                                          'Location': location,
                                          'Rating': rating,
                                          'Date': date,
                                          "Salary": salary,
                                          "Description": description,
                                          "Links": links}])], ignore_index=True)
        print("Job number {0:4d} added - {1:s}".format(jn,title))
# Out:
# Job number    1 added - Data Scientist
# Job number    2 added - Data Scientist (All Levels)
# Job number    3 added - Data Scientist - RWD
# Job number    4 added - Jr. Data Scientist
# Job number    5 added - Machine Learning Engineer
# Job number    6 added - Data Scientist
# Job number    7 added - Data Scientist (US Remote Eligible)
# Job number    8 added - Data Scientist
# Job number    9 added - Jr. Data Scientist
# Job number   10 added - Associate Data Scientist
# Job number   11 added - Computational Biologist / Data Scientist
# Job number   12 added - Interdisciplinary-Microbiologist/Data Scientist
# Job number   13 added - Junior Data Scientist
# Job number   14 added - Data Scientist I, Product Analytics
# Job number   15 added - Senior Data Scientist
# Job number   16 added - Data Scientist
# Job number   17 added - Data Scientist jobs
# Job number   18 added - Data Scientist
# Job number   19 added - Data Scientist / NLP (Python, Django/Flask, NLP, Clustering, Rest API)
# Job number   20 added - Senior Data Analyst
# Job number   21 added - Business Analyst (AI Governance)
# Job number   22 added - Data Scientist
# Job number   23 added - Data Scientist - Fully remote
# Job number   24 added - Data Scientist
# Job number   25 added - Data Scientist
# Job number   26 added - Healthcare Data Scientist
# Job number   27 added - Data Scientist - Machine Learning Ops
# Job number   28 added - Data Scientist, Ecosystem
# Job number   29 added - Data Scientist-Health
# Job number   30 added - Data Scientist
# Job number   31 added - Data Scientist - REMOTE
# Job number   32 added - Data Scientist - Remote or Hybrid
# Job number   33 added - Data Scientist
# Job number   34 added - Data Scientist, CV/NLP
# Job number   35 added - Data Scientist
# Job number   36 added - Sr. Data Analyst
# Job number   37 added - Data Scientist
# Job number   38 added - Senior Data Scientist
# Job number   39 added - Data Scientist
# Job number   40 added - Data Scientist
# Job number   41 added - Data Scientist
# Job number   42 added - Data Scientist (Engineer II)
# Job number   43 added - Data Scientist (Hybrid)
# Job number   44 added - Data Scientist I
# Job number   45 added - Data Scientist (Remote)
# Job number   46 added - AI engineer
# Job number   47 added - Data Scientist, Customer Experimentation
# Job number   48 added - Data Scientist
# Job number   49 added - ML Engineer - Entry Level
# Job number   50 added - Senior Data Analyst
# Job number   51 added - Sr. Data Scientist II (Remote)
# Job number   52 added - Data Scientist
# Job number   53 added - Data Scientist, Abuse Prevention
# Job number   54 added - Associate Data Scientist (Remote)
# Job number   55 added - Data Scientist, Machine Learning
# Job number   56 added - Data Scientist / Machine Learning Engineer
# Job number   57 added - Senior Data Scientist (CBP Clearance)
# Job number   58 added - Python Developer (NLP)
# Job number   59 added - Data Scientist
# Job number   60 added - Azure Data Engineer (Remote)
# Job number   61 added - Lead Data Scientist
# Job number   62 added - Data Scientist
# Job number   63 added - Senior Data Analyst
# Job number   64 added - Data Forensics Scientist
# Job number   65 added - Data Scientist
# Job number   66 added - Senior Data Scientist
# Job number   67 added - Principal Data Scientist, Member Experience
# Job number   68 added - Data Scientist or Statistician, Postdoc
# Job number   69 added - Staff Data Scientist
# Job number   70 added - Predictive Data Analyst - Remote Opportunity - SimioCloud
# Job number   71 added - Data Scientist (Manufacturing)
# Job number   72 added - Manager, Data Science
# Job number   73 added - Data Scientist - W2 no C2C
# Job number   74 added - Sr. Health Data Analyst Remote
# Job number   75 added - Digital Transformation/Data Science Student Employee
# Job number   76 added - Data Scientist
# Job number   77 added - Data Scientist
# Job number   78 added - Applied Data Scientist
# Job number   79 added - AI Research Engineer
# Job number   80 added - Data Scientist
# Job number   81 added - Data Scientist I
# Job number   82 added - Data Scientist
# Job number   83 added - Data Scientist
# Job number   84 added - Data Scientist - Risk & Analytics
# Job number   85 added - Sr Provider Data Analyst - Remote
# Job number   86 added - Data Scientist
# Job number   87 added - Senior Data Scientist (REMOTE POSITION)
# Job number   88 added - Program Integrity Data Scientist
# Job number   89 added - Data Scientist
# Job number   90 added - Data Scientist (GeoMatch)
# Job number   91 added - Data Scientist
# Job number   92 added - Data Scientist - Remote
# Job number   93 added - Sr. Data Analyst
# Job number   94 added - Data Scientist
# Job number   95 added - Python Machine Learning Developer
# Job number   96 added - Senior Data Scientist
# Job number   97 added - Sr. Data Analyst
# Job number   98 added - Data Scientist, Space Optimization (Remote)
# Job number   99 added - Data Scientist
# Job number  100 added - Sr. Data Analyst I
# Job number  101 added - Senior Data Scientist
# Job number  102 added - Data Scientist
# Job number  103 added - Data Scientist
# Job number  104 added - Senior Data Science Manager
# Job number  105 added - Data Scientist
# Job number  106 added - Data Scientist
# Job number  107 added - Data Scientist - Location Analytics
# Job number  108 added - Senior Data Analyst
# Job number  109 added - Data Scientist
# Job number  110 added - Manager, CRM Data Science Analytics
# Job number  111 added - Data Scientist/Senior Data Scientist
# Job number  112 added - Data Scientist
# Job number  113 added - Data Analytics Director
# Job number  114 added - Data Scientist
# Job number  115 added - Data Scientist
# Job number  116 added - Data Scientist
# Job number  117 added - Data Scientist/Applied Researcher
# Job number  118 added - Data Scientist
# Job number  119 added - Data Scientist
# Job number  120 added - Senior Data Scientist
# Job number  121 added - Data Scientist
# Job number  122 added - AI Reports Developer / Analyst
# Job number  123 added - Data Scientist
# Job number  124 added - Conversational AI Developer
# Job number  125 added - Machine Learning Engineer
# Job number  126 added - Data Scientist
# Job number  127 added - Data Scientist (Remote)
# Job number  128 added - Data Scientist - remote
# Job number  129 added - Data Specialist
# Job number  130 added - Mid-Level Data Scientist
# Job number  131 added - Senior Data Scientist - Digital Bidding
# Job number  132 added - Senior Applied Scientist - NLP
# Job number  133 added - Data Scientist (Remote)
# Job number  134 added - Senior Data Scientist
# Job number  135 added - Job Open for Data Scientist with Azure_Remote
# Job number  136 added - Data Scientist
# Job number  137 added - Data Engineer
# Job number  138 added - Data Scientist I
# Job number  139 added - Data Scientist (Remote)
# Job number  140 added - Data Scientist
# Job number  141 added - Data Visualization Specialist
# Job number  142 added - Data Engineer - Remote Opportunity - SimioCloud
# Job number  143 added - Sr. Data Analyst
# Job number  144 added - Machine Learning Engineer (Remote)
# Job number  145 added - Data Scientist
# Job number  146 added - Data Engineer/Data Scientist
# Job number  147 added - Data Scientist
# Job number  148 added - Data Scientist
# Job number  149 added - Artificial Intelligence Developer
# Job number  150 added - Data Scientist, Statistics

# %%
driver.quit()

# %% [markdown]
# ### Scrape full job descriptions

# %%
Links_list = dataframe['Links'].tolist()
#Links_list

# %%
import random
import time

# %%
driver = webdriver.Firefox(executable_path=driver_path)
descriptions=[]
for i in Links_list:
    driver.get(i)
    driver.implicitly_wait(random.randint(3, 8))
    jd = driver.find_element(By.XPATH, '//div[@id="jobDescriptionText"]').text
    descriptions.append(jd)
    time.sleep(random.randint(5,10))

dataframe['Descriptions'] = descriptions
# Out:
# /var/folders/x_/gv_25j4x4yv_w8_mmgvv_2th0000gn/T/ipykernel_17487/3289258759.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Firefox(executable_path=driver_path)

# %%
driver.quit()

# %% [markdown]
# ### Save results

# %%
# Convert the dataframe to a csv file
date = datetime.today().strftime('%Y-%m-%d')
# dataframe.to_csv(date + "_" + position + "_" + locations + ".csv", index=False)

# %%
dataframe
# Out:
#                                  Title                             Company  \
# 0                       Data Scientist                   Data Products LLC
# 1          Data Scientist (All Levels)                              Noblis
# 2                 Data Scientist - RWD                           Norstella
# 3                   Jr. Data Scientist                          Net2Aspire
# 4            Machine Learning Engineer                        Idea Evolver
# ..                                 ...                                 ...
# 145       Data Engineer/Data Scientist                        etrailer.com
# 146                     Data Scientist                         ECS Federal
# 147                     Data Scientist                      Mashvisor Inc.
# 148  Artificial Intelligence Developer  Ultrafly Solutions private limited
# 149         Data Scientist, Statistics                            Pairwise
#
#                        Location Rating                       Date  \
# 0                        Remote    NaN                PostedToday
# 1    Remote in Reston, VA 20191    4.0                PostedToday
# 2                        Remote    NaN  EmployerActive 5 days ago
# 3                        Remote    NaN  EmployerActive 4 days ago
# 4                        Remote    NaN  EmployerActive 4 days ago
# ..                          ...    ...                        ...
# 145                      Remote    3.2  PostedPosted 30+ days ago
# 146                      Remote    NaN  EmployerActive 5 days ago
# 147           +1 locationRemote    3.0    PostedPosted 5 days ago
# 148                      Remote    NaN     PostedPosted 1 day ago
# 149  Remote in Durham, NC 27701    NaN  PostedPosted 30+ days ago
#
#                          Salary  \
# 0     $80,000 - $120,000 a year
# 1                           NaN
# 2    $125,000 - $175,000 a year
# 3      $65,000 - $80,000 a year
# 4    $120,000 - $160,000 a year
# ..                          ...
# 145  $100,000 - $180,000 a year
# 146  $140,000 - $160,000 a year
# 147                         NaN
# 148                         NaN
# 149             $120,000 a year
#
#                                            Description  \
# 0    Present information using data visualization t...
# 1    In your role, you will work on multiple projec...
# 2    Design data pipelines and queries and analyze ...
# 3     Create data dashboards and other data visual...
# 4    Work with product developers (tech regulatory,...
# ..                                                 ...
# 145  Experienced in designing, implementing, and ma...
# 146  5 years of analytics experience with designing...
# 147  Develop machine learning models, write product...
# 148  Collaborate with data scientists and other sta...
# 149  Strong proficiency in data visualization and p...
#
#                                                  Links  \
# 0    https://www.indeed.com/company/Data-Products-L...
# 1    https://www.indeed.com/rc/clk?jk=b8f1b308b3018...
# 2    https://www.indeed.com/company/NorStella/jobs/...
# 3    https://www.indeed.com/company/net2aspire/jobs...
# 4    https://www.indeed.com/pagead/clk?mo=r&ad=-6NY...
# ..                                                 ...
# 145  https://www.indeed.com/rc/clk?jk=1292d743fbc2f...
# 146  https://www.indeed.com/company/ERPi/jobs/Data-...
# 147  https://www.indeed.com/rc/clk?jk=007e70ed4a993...
# 148  https://www.indeed.com/company/Ultrafly-Soluti...
# 149  https://www.indeed.com/rc/clk?jk=2313e7140f3bb...
#
#                                           Descriptions
# 0    About us\nWe are professional and data-driven....
# 1    Responsibilities:\nNoblis is seeking to hire D...
# 2    Job Summary:\nWe are seeking an experienced Da...
# 3     Apply Statistical and Machine Learning metho...
# 4    Company Overview\nIdea Evolver specializes in ...
# ..                                                 ...
# 145  Mid-to-Senior Level Data Engineer/Data Scienti...
# 146  ECS is seeking a Data Scientist to work fully ...
# 147  Build the solution that transforms the real es...
# 148  We are seeking an experienced Artificial Intel...
# 149  Job Title: Data Scientist, Statistics\nReporti...
#
# [150 rows x 9 columns]
